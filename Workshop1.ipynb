# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
from PIL import Image

# %%
image_colored = Image.open("/content/drive/MyDrive/AI and Machine Learning/DSC03641.JPG")

# %%
print("Format:", image_colored.format)
print("Size:", image_colored.size)
print("Mode:", image_colored.mode)
# Out:
# Format: JPEG
# Size: (4000, 3000)
# Mode: RGB

# %%
image_colored = image_colored.convert("RGB")
print(image_colored.mode)
# Out:
# RGB

# %% [markdown]
# Converting to Grayscale

# %%
image_grayed = image_colored.convert('L')
display(image_grayed)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
print(image_grayed.size)
print(image_grayed.format)
print(image_grayed.mode)
# Out:
# (4000, 3000)
# None
# L

# %%
width, height = image_grayed.size
channels = len(image_grayed.getbands())

print(f"Image shape (gray:({height}, {width}, {channels}))")

image_size_grayed = width *height* 1

print(f"Image size (gray): { image_size_grayed}")
# Out:
# Image shape (gray:(3000, 4000, 1))
# Image size (gray): 12000000

# %%
width , height = image_colored.size

channels = len(image_grayed.getbands()) #for RGB it is 3

print(f"Image shape (gray:({height}, {width}, {channels}))")

image_size_colored = width *height* 3

print(f"Image size (gray): { image_size_colored}")
# Out:
# Image shape (gray:(3000, 4000, 1))
# Image size (gray): 36000000

# %%
import numpy as np
image_array_colored = np.array(image_colored)
image_array_colored.shape
# Out:
# (3000, 4000, 3)

# %%
image_array_grayed = np.array(image_grayed)
image_array_grayed.shape
# Out:
# (3000, 4000)

# %% [markdown]
# Accessing individual  channels

# %%
red_channel = image_array_colored [: , : , 0]  # 0 for Red Channel
print(red_channel)
display(Image.fromarray(red_channel))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
red_channel= image_array_colored.copy()
red_channel [ :, : , 1] = 0
red_channel [:, :, 2]= 0

print(red_channel)
display(Image.fromarray(red_channel))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
green_channel = image_array_colored.copy()
green_channel [:, :, 0] = 0
green_channel [:, :, 2] = 0

print(green_channel)
display(Image.fromarray(green_channel))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
blue_channel = image_array_colored.copy()
blue_channel [:, :, 0] = 0
blue_channel [:, :, 1] = 0

print(blue_channel)
display(Image.fromarray(blue_channel))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
row_100 = image_array_colored[100,:,:]
print(row_100)
# Out:
# [[172 124 162]
#  [170 122 160]
#  [170 123 157]
#  ...
#  [ 60  61  63]
#  [ 57  58  62]
#  [ 55  56  60]]

# %%
col_50 = image_array_colored[:, 50, :]
print(col_50)
# Out:
# [[204 150 186]
#  [197 141 178]
#  [189 133 170]
#  ...
#  [ 46  44  47]
#  [ 43  41  42]
#  [ 54  52  53]]

# %%
pixel = image_array_colored[10, 50, :]
print(pixel)
# Out:
# [175 128 162]

# %% [markdown]
# Cropping the Image

# %%
left = 100
upper = 50
right = 200
lower = 150

cropped_image = image_colored.crop ((left, upper, right, lower))
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
image_array = np.zeros((100, 100, 3), dtype = np.uint8)
image_from_array = Image. fromarray(image_array)
image_from_array.show()
display( image_from_array)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
image_array = np.ones((100, 100, 3), dtype = np.uint8)
image_from_array = Image. fromarray(image_array)
image_from_array.show()
display( image_from_array)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# Saving any Image

# %%
image_grayed.save("output_image.jpg")

# %% [markdown]
# PCA

# %%
import numpy as np
import matplotlib.pyplot as plt
from  PIL import Image
